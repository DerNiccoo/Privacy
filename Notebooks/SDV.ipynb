# %%
from sdv import load_demo

metadata, tables = load_demo(metadata=True)

# %%
metadata
# Out:
# Metadata
#   root_path: .
#   tables: ['users', 'sessions', 'transactions']
#   relationships:
#     sessions.user_id -> users.user_id
#     transactions.session_id -> sessions.session_id

# %%
tables
# Out:
# {'users':    user_id country gender  age
#  0        0      US      M   34
#  1        1      UK      F   23
#  2        2      ES   None   44
#  3        3      UK      M   22
#  4        4      US      F   54
#  5        5      DE      M   57
#  6        6      BG      F   45
#  7        7      ES   None   41
#  8        8      FR      F   23
#  9        9      UK   None   30,
#  'sessions':    session_id  user_id  device       os  minutes
#  0           0        0  mobile  android       23
#  1           1        1  tablet      ios       12
#  2           2        1  tablet  android        8
#  3           3        2  mobile  android       13
#  4           4        4  mobile      ios        9
#  5           5        5  mobile  android       32
#  6           6        6  mobile      ios        7
#  7           7        6  tablet      ios       21
#  8           8        6  mobile      ios       29
#  9           9        8  tablet      ios       34,
#  'transactions':    transaction_id  session_id           timestamp  amount  cancelled
#  0               0           0 2019-01-01 12:34:32   100.0      False
#  1               1           0 2019-01-01 12:42:21    55.3      False
#  2               2           1 2019-01-07 17:23:11    79.5      False
#  3               3           3 2019-01-10 11:08:57   112.1       True
#  4               4           5 2019-01-10 21:54:08   110.0       True
#  5               5           5 2019-01-11 11:21:20    76.3      False
#  6               6           7 2019-01-22 14:44:10    89.5      False
#  7               7           8 2019-01-23 10:14:09   132.1       True
#  8               8           9 2019-01-27 16:09:17    68.0      False
#  9               9           9 2019-01-29 12:10:48    99.9      False}

# %%
from sdv import SDV
sdv = SDV()

# %%
sdv.fit(metadata, tables)

# %%
sampled = sdv.sample_all()

# %%
sampled
# Out:
# {'users':    user_id country gender  age
#  0        0      UK      M   37
#  1        1      US    NaN   32
#  2        2      US    NaN   34
#  3        3      ES      M   49
#  4        4      FR      M   45
#  5        5      ES    NaN   52
#  6        6      FR      F   41
#  7        7      UK      M   37
#  8        8      UK      M   36
#  9        9      US    NaN   40,
#  'sessions':    session_id  user_id  device       os  minutes
#  0           0        0  tablet      ios       16
#  1           1        1  mobile      ios       32
#  2           2        4  tablet      ios       18
#  3           3        6  mobile      ios       20
#  4           4        7  tablet      ios       10
#  5           5        8  mobile  android        2,
#  'transactions':    transaction_id  session_id           timestamp      amount  cancelled
#  0               0           1 2019-01-08 10:55:05   52.042499      False
#  1               1           2 2019-01-25 05:36:13  134.707226       True
#  2               2           3 2019-01-16 19:21:11  102.500261       True
#  3               3           3 2019-01-16 15:17:24   48.487311       True}

# %%
import pandas as pd
import sqlite3

def sql_identifier(s):
    return '"' + s.replace('"', '""') + '"'

def prepareDB(path):
    db = sqlite3.connect(path)
    rows = db.execute("SELECT name FROM sqlite_master WHERE type = 'table'")
    tables = [row[0].lower() for row in rows]
    tables.remove('sqlite_sequence')
    
    tables_df = {}
    
    for table in tables:
        tables_df[table] = pd.read_sql_query('SELECT * from ' + table, db)
        
        rows = db.execute("PRAGMA table_info({})".format(sql_identifier(table)))
        attributes = rows.fetchall()
        
        pk = []
        for attr in attributes:
            if attr[5] == 1:
                pk.append(attr[1])
        print(table)
        print(pk)
        
        rows = db.execute("PRAGMA foreign_key_list({})".format(sql_identifier(table)))
        foreign_key_list = rows.fetchall()
        fkeys = []
        for fk in foreign_key_list:
            fkeys.append((fk[2].lower(), fk[3], fk[4]))
        print(fkeys)        
        
    return tables_df

# %%
tables = prepareDB('soccer.sqlite')
# Out:
# player_attributes
# ['id']
# [('player', 'player_api_id', 'player_api_id'), ('player', 'player_fifa_api_id', 'player_fifa_api_id')]
# player
# ['id']
# []
# match
# ['id']
# [('player', 'away_player_11', 'player_api_id'), ('player', 'away_player_10', 'player_api_id'), ('player', 'away_player_9', 'player_api_id'), ('player', 'away_player_8', 'player_api_id'), ('player', 'away_player_7', 'player_api_id'), ('player', 'away_player_6', 'player_api_id'), ('player', 'away_player_5', 'player_api_id'), ('player', 'away_player_4', 'player_api_id'), ('player', 'away_player_3', 'player_api_id'), ('player', 'away_player_2', 'player_api_id'), ('player', 'away_player_1', 'player_api_id'), ('player', 'home_player_11', 'player_api_id'), ('player', 'home_player_10', 'player_api_id'), ('player', 'home_player_9', 'player_api_id'), ('player', 'home_player_8', 'player_api_id'), ('player', 'home_player_7', 'player_api_id'), ('player', 'home_player_6', 'player_api_id'), ('player', 'home_player_5', 'player_api_id'), ('player', 'home_player_4', 'player_api_id'), ('player', 'home_player_3', 'player_api_id'), ('player', 'home_player_2', 'player_api_id'), ('player', 'home_player_1', 'player_api_id'), ('team', 'away_team_api_id', 'team_api_id'), ('team', 'home_team_api_id', 'team_api_id'), ('league', 'league_id', 'id'), ('country', 'country_id', 'id')]
# league
# ['id']
# [('country', 'country_id', 'id')]
# country
# ['id']
# []
# team
# ['id']
# []
# team_attributes
# ['id']
# [('team', 'team_api_id', 'team_api_id'), ('team', 'team_fifa_api_id', 'team_fifa_api_id')]

# %%
import numpy as np

df_train = {}
df_train['player'] = tables['player'].sample(n=100)
boolean_series = tables['player_attributes'].player_api_id.isin(df_train['player'].player_api_id)
df_train['player_attributes'] = tables['player_attributes'][boolean_series]

# %%
for k, v in df_train.items():
    df_train[k] = df_train[k].replace([np.inf, -np.inf], np.nan)
    df_train[k] = df_train[k].dropna()

# %%
df_train['player'][df_train['player'].isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, player_api_id, player_name, player_fifa_api_id, birthday, height, weight]
# Index: []

# %%
df_train['player_attributes'][df_train['player_attributes'].isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, player_fifa_api_id, player_api_id, date, overall_rating, potential, preferred_foot, attacking_work_rate, defensive_work_rate, crossing, finishing, heading_accuracy, short_passing, volleys, dribbling, curve, free_kick_accuracy, long_passing, ball_control, acceleration, sprint_speed, agility, reactions, balance, shot_power, jumping, stamina, strength, long_shots, aggression, interceptions, positioning, vision, penalties, marking, standing_tackle, sliding_tackle, gk_diving, gk_handling, gk_kicking, gk_positioning, gk_reflexes]
# Index: []
#
# [0 rows x 42 columns]

# %%
from sdv import Metadata

metadata = Metadata()
metadata
# Out:
# Metadata
#   root_path: .
#   tables: []
#   relationships:

# %%
metadata.add_table(
    name='player',
    data=df_train['player'],
    primary_key='id'
)

# %%
metadata.add_table(
    name='player_attributes',
    data=df_train['player_attributes'],
    primary_key='id',
)

# %%
metadata
# Out:
# Metadata
#   root_path: .
#   tables: ['player_attributes', 'player']
#   relationships:

# %%
metadata.add_relationship(
    parent='player',
    child='player_attributes',
    foreign_key='player_fifa_api_id',
    parent_key='player_fifa_api_id'
)

# %%
metadata.add_relationship(
    parent='player',
    child='player_attributes',
    foreign_key='player_api_id',
    parent_key='player_api_id'
)

# %%
metadata
# Out:
# Metadata
#   root_path: .
#   tables: ['player_attributes', 'player']
#   relationships:
#     player_attributes.player_fifa_api_id -> player.id
#     player_attributes.player_api_id -> player.id

# %%
metadata.to_dict()
# Out:
# {'tables': {'player_attributes': {'fields': {'id': {'type': 'id',
#      'subtype': 'integer'},
#     'player_fifa_api_id': {'type': 'id',
#      'subtype': 'integer',
#      'ref': {'table': 'player', 'field': 'player_fifa_api_id'}},
#     'player_api_id': {'type': 'id',
#      'subtype': 'integer',
#      'ref': {'table': 'player', 'field': 'player_api_id'}},
#     'date': {'type': 'categorical'},
#     'overall_rating': {'type': 'numerical', 'subtype': 'float'},
#     'potential': {'type': 'numerical', 'subtype': 'float'},
#     'preferred_foot': {'type': 'categorical'},
#     'attacking_work_rate': {'type': 'categorical'},
#     'defensive_work_rate': {'type': 'categorical'},
#     'crossing': {'type': 'numerical', 'subtype': 'float'},
#     'finishing': {'type': 'numerical', 'subtype': 'float'},
#     'heading_accuracy': {'type': 'numerical', 'subtype': 'float'},
#     'short_passing': {'type': 'numerical', 'subtype': 'float'},
#     'volleys': {'type': 'numerical', 'subtype': 'float'},
#     'dribbling': {'type': 'numerical', 'subtype': 'float'},
#     'curve': {'type': 'numerical', 'subtype': 'float'},
#     'free_kick_accuracy': {'type': 'numerical', 'subtype': 'float'},
#     'long_passing': {'type': 'numerical', 'subtype': 'float'},
#     'ball_control': {'type': 'numerical', 'subtype': 'float'},
#     'acceleration': {'type': 'numerical', 'subtype': 'float'},
#     'sprint_speed': {'type': 'numerical', 'subtype': 'float'},
#     'agility': {'type': 'numerical', 'subtype': 'float'},
#     'reactions': {'type': 'numerical', 'subtype': 'float'},
#     'balance': {'type': 'numerical', 'subtype': 'float'},
#     'shot_power': {'type': 'numerical', 'subtype': 'float'},
#     'jumping': {'type': 'numerical', 'subtype': 'float'},
#     'stamina': {'type': 'numerical', 'subtype': 'float'},
#     'strength': {'type': 'numerical', 'subtype': 'float'},
#     'long_shots': {'type': 'numerical', 'subtype': 'float'},
#     'aggression': {'type': 'numerical', 'subtype': 'float'},
#     'interceptions': {'type': 'numerical', 'subtype': 'float'},
#     'positioning': {'type': 'numerical', 'subtype': 'float'},
#     'vision': {'type': 'numerical', 'subtype': 'float'},
#     'penalties': {'type': 'numerical', 'subtype': 'float'},
#     'marking': {'type': 'numerical', 'subtype': 'float'},
#     'standing_tackle': {'type': 'numerical', 'subtype': 'float'},
#     'sliding_tackle': {'type': 'numerical', 'subtype': 'float'},
#     'gk_diving': {'type': 'numerical', 'subtype': 'float'},
#     'gk_handling': {'type': 'numerical', 'subtype': 'float'},
#     'gk_kicking': {'type': 'numerical', 'subtype': 'float'},
#     'gk_positioning': {'type': 'numerical', 'subtype': 'float'},
#     'gk_reflexes': {'type': 'numerical', 'subtype': 'float'}},
#    'primary_key': 'id'},
#   'player': {'fields': {'id': {'type': 'id', 'subtype': 'integer'},
#     'player_api_id': {'type': 'id', 'subtype': 'integer'},
#     'player_name': {'type': 'categorical'},
#     'player_fifa_api_id': {'type': 'id', 'subtype': 'integer'},
#     'birthday': {'type': 'categorical'},
#     'height': {'type': 'numerical', 'subtype': 'float'},
#     'weight': {'type': 'numerical', 'subtype': 'integer'}},
#    'primary_key': 'id'}}}

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
metadata
# Out:
# Metadata
#   root_path: .
#   tables: ['player_attributes', 'player']
#   relationships:
#     player_attributes.player_fifa_api_id -> player.id
#     player_attributes.player_api_id -> player.id

# %%
from sdv.relational import HMA1

model = HMA1(metadata)
model.fit(df_train)

# %%
new_data = model.sample()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-62b1ae9d6493> in <module>
# ----> 1 new_data = model.sample()
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\relational\base.py in sample(self, table_name, num_rows, sample_children, reset_primary_keys)
#     182             self._reset_primary_keys_generators()
#     183
# --> 184         return self._sample(table_name, num_rows, sample_children)
#     185
#     186     def save(self, path):
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\relational\hma.py in _sample(self, table_name, num_rows, sample_children)
#     469         for table in self.metadata.get_tables():
#     470             if not self.metadata.get_parents(table):
# --> 471                 self._sample_table(table, num_rows, sampled_data=sampled_data)
#     472
#     473         return self._finalize(sampled_data)
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\relational\hma.py in _sample_table(self, table_name, num_rows, sample_children, sampled_data)
#     428
#     429         if sample_children:
# --> 430             self._sample_children(table_name, sampled_data, table_rows)
#     431
#     432         return sampled_data
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\relational\hma.py in _sample_children(self, table_name, sampled_data, table_rows)
#     350                 LOGGER.info('Sampling rows from child table %s', child_name)
#     351                 for _, row in table_rows.iterrows():
# --> 352                     self._sample_child_rows(child_name, table_name, row, sampled_data)
#     353
#     354                 child_rows = sampled_data[child_name]
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\relational\hma.py in _sample_child_rows(self, table_name, parent_name, parent_row, sampled_data)
#     331         table_meta = self._models[table_name].get_metadata()
#     332         model = self._model(table_metadata=table_meta)
# --> 333         model.set_parameters(parameters)
#     334
#     335         table_rows = self._sample_rows(model, table_name)
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\tabular\base.py in set_parameters(self, parameters)
#     467
#     468         if self._metadata.get_dtypes(ids=False):
# --> 469             self._set_parameters(parameters)
#     470
#     471     def save(self, path):
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\tabular\copulas.py in _set_parameters(self, parameters)
#     460         """
#     461         parameters = unflatten_dict(parameters)
# --> 462         parameters = self._rebuild_gaussian_copula(parameters)
#     463
#     464         self._model = copulas.multivariate.GaussianMultivariate.from_dict(parameters)
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\tabular\copulas.py in _rebuild_gaussian_copula(self, model_parameters)
#     446         covariance = model_parameters.get('covariance')
#     447         if covariance:
# --> 448             model_parameters['covariance'] = self._rebuild_correlation_matrix(covariance)
#     449         else:
#     450             model_parameters['covariance'] = [[1.0]]
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\tabular\copulas.py in _rebuild_correlation_matrix(cls, triangular_covariance)
#     418         correlation += np.identity(size)
#     419
# --> 420         return cls._get_nearest_correlation_matrix(correlation).tolist()
#     421
#     422     def _rebuild_gaussian_copula(self, model_parameters):
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdv\tabular\copulas.py in _get_nearest_correlation_matrix(matrix)
#     356         Insipired by: https://stackoverflow.com/a/63131250
#     357         """
# --> 358         eigenvalues, eigenvectors = scipy.linalg.eigh(matrix)
#     359         negative = eigenvalues < 0
#     360         identity = np.identity(len(matrix))
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\linalg\decomp.py in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     443                          ''.format(driver, '", "'.join(drv_str[1:])))
#     444
# --> 445     a1 = _asarray_validated(a, check_finite=check_finite)
#     446     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     447         raise ValueError('expected square "a" matrix')
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\_lib\_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     261             raise ValueError('masked arrays are not supported')
#     262     toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 263     a = toarray(a)
#     264     if not objects_ok:
#     265         if a.dtype is np.dtype('O'):
#
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
#     486     a = asarray(a, dtype=dtype, order=order)
#     487     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 488         raise ValueError(
#     489             "array must not contain infs or NaNs")
#     490     return a
#
# ValueError: array must not contain infs or NaNs

# %%
from sdv.tabular import CTGAN

# %%
model = CTGAN()
model.fit(df_train['player_attributes'])

# %%
new_data = model.sample(200)

# %%
new_data

# %%
import pandas as pd

# %%
custom_df = pd.read_csv('Customer Segmentation/Train.csv')

# %%
custom_df = custom_df.set_index('ID')

# %%
model = CTGAN()
model.fit(custom_df)
# Out:
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:147: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   label = cluster.KMeans(n_clusters=self.n_components, n_init=1,

# %%
custom_df[:200]
# Out:
#         Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# ID
# 462809    Male           No   22        No     Healthcare              1.0
# 462643  Female          Yes   38       Yes       Engineer              NaN
# 466315  Female          Yes   67       Yes       Engineer              1.0
# 461735    Male          Yes   67       Yes         Lawyer              0.0
# 462669  Female          Yes   40       Yes  Entertainment              NaN
# ...        ...          ...  ...       ...            ...              ...
# 466544    Male          Yes   41       Yes      Executive              1.0
# 463610  Female          Yes   31       Yes         Artist              0.0
# 465539  Female          Yes   49       Yes         Artist              1.0
# 459823    Male          Yes   67       Yes      Executive              1.0
# 467614    Male          Yes   35        No         Artist              4.0
#
#        Spending_Score  Family_Size  Var_1 Segmentation
# ID
# 462809            Low          4.0  Cat_4            D
# 462643        Average          3.0  Cat_4            A
# 466315            Low          1.0  Cat_6            B
# 461735           High          2.0  Cat_6            B
# 462669           High          6.0  Cat_6            A
# ...               ...          ...    ...          ...
# 466544        Average          3.0  Cat_6            A
# 463610        Average          2.0  Cat_6            A
# 465539           High          5.0  Cat_6            B
# 459823            Low          2.0  Cat_6            A
# 467614        Average          2.0  Cat_6            B
#
# [200 rows x 10 columns]

# %%
new_data = model.sample(200)
new_data
# Out:
#      Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0      Male          Yes   44        No  Entertainment         0.080007
# 1    Female           No   17       Yes     Healthcare        -0.004656
# 2      Male          Yes   77        No      Executive         1.002408
# 3      Male           No   18        No     Healthcare         1.015226
# 4    Female          Yes   51       Yes         Artist         1.030877
# ..      ...          ...  ...       ...            ...              ...
# 195  Female           No   27        No       Engineer        -0.010397
# 196  Female          Yes   88       Yes         Lawyer         1.023613
# 197    Male           No   42       Yes         Artist         0.994560
# 198  Female           No   50       Yes  Entertainment         8.596709
# 199  Female          Yes   72       Yes         Lawyer         1.093455
#
#     Spending_Score  Family_Size  Var_1 Segmentation
# 0          Average     5.041996  Cat_4            A
# 1              Low     1.023081  Cat_6            D
# 2             High     5.046882  Cat_4            A
# 3              Low     2.979587  Cat_2            D
# 4              Low     4.012221  Cat_6            B
# ..             ...          ...    ...          ...
# 195            Low     3.990666  Cat_3            D
# 196           High     2.007848  Cat_6            B
# 197            Low     4.016569  Cat_6            C
# 198            Low     1.019549  Cat_6            A
# 199           High     4.024305  Cat_6            B
#
# [200 rows x 10 columns]

# %%
model.save('CTGAN_customer.pkl')

# %%
df_train['player']
# Out:
#           id  player_api_id        player_name  player_fifa_api_id  \
# 8204    8216         159352  Ousmane Coulibaly              190658
# 10705  10721         166019       Wahbi Khazri              194845
# 9383    9397         477604         Salva Ruiz              210747
# 9622    9637         602211        Seko Fofana              216320
# 7842    7854         265913       Nene Bonilha              203211
# ...      ...            ...                ...                 ...
# 8522    8536         163605               Pele              194020
# 6564    6574         164316           Marafona              200798
# 10221  10237         278838         Thomas Lam              208018
# 10921  10937          34443        Yoann Folly              138682
# 7031    7042         244065       Matan Ohayon              202120
#
#                   birthday  height  weight
# 8204   1989-07-09 00:00:00  182.88     165
# 10705  1991-02-08 00:00:00  182.88     168
# 9383   1995-05-17 00:00:00  177.80     161
# 9622   1995-05-07 00:00:00  182.88     170
# 7842   1992-02-17 00:00:00  175.26     154
# ...                    ...     ...     ...
# 8522   1991-09-29 00:00:00  182.88     170
# 6564   1987-05-08 00:00:00  190.50     190
# 10221  1993-12-18 00:00:00  187.96     168
# 10921  1985-06-06 00:00:00  175.26     163
# 7031   1986-02-25 00:00:00  180.34     159
#
# [100 rows x 7 columns]

# %%
from sdv.tabular import GaussianCopula
from sdv.tabular import CTGAN
from sdv.tabular import CopulaGAN
from sdv.tabular import TVAE
from sdv.evaluation import evaluate

# %%
def testModel(_model, data):
    model = _model()
    model.fit(data)
    new_data = model.sample()
    _score = evaluate(new_data, data, aggregate=False)
    score = evaluate(new_data, data)
    return (_score, score)

# %%
score = testModel(GaussianCopula, df_train['player_attributes'])
# Out:
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\stats\_continuous_distns.py:4965: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\stats\_continuous_distns.py:621: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\copulas\univariate\truncated_gaussian.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   a = (self.min - loc) / scale
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\copulas\univariate\truncated_gaussian.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   b = (self.max - loc) / scale
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\optimize\optimize.py:700: RuntimeWarning: invalid value encountered in subtract
#   np.max(np.abs(fsim[0] - fsim[1:])) <= fatol):
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\copulas\univariate\truncated_gaussian.py:43: RuntimeWarning: divide by zero encountered in double_scalars
#   a = (self.min - loc) / scale
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\copulas\univariate\truncated_gaussian.py:44: RuntimeWarning: invalid value encountered in double_scalars
#   b = (self.max - loc) / scale
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_data[pd.isnull(real_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\pandas\core\frame.py:3089: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   synthetic_data[pd.isnull(synthetic_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-10 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-03-06 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-02-20 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-15 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-02-15 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-20 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2012-08-31 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-09-21 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2008-08-30 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2011-02-22 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2012-02-22 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2011-08-30 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-09-18 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2012-02-22 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-03-06 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2010-02-22 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2012-08-31 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-06 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-15 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(preferred_foot='left', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(preferred_foot='left', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='None', defensive_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_data[pd.isnull(real_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\pandas\core\frame.py:3089: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   synthetic_data[pd.isnull(synthetic_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-10 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-03-06 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-02-20 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-15 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-02-15 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-20 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2012-08-31 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-09-21 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2008-08-30 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2011-02-22 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2012-02-22 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2011-08-30 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-09-18 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2012-02-22 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-03-06 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2010-02-22 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2012-08-31 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-06 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-15 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(preferred_foot='left', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(preferred_foot='left', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='None', defensive_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')

# %%
score
# Out:
# (                    metric                                     name  \
#  0          BNLogLikelihood           BayesianNetwork Log Likelihood
#  1        LogisticDetection             LogisticRegression Detection
#  2             SVCDetection                            SVC Detection
#  11         GMLogLikelihood           GaussianMixture Log Likelihood
#  12                  CSTest                              Chi-Squared
#  13                  KSTest  Inverted Kolmogorov-Smirnov D statistic
#  14          KSTestExtended  Inverted Kolmogorov-Smirnov D statistic
#  15  ContinuousKLDivergence   Continuous Kullback–Leibler Divergence
#  16    DiscreteKLDivergence     Discrete Kullback–Leibler Divergence
#
#           score  min_value  max_value      goal
#  0    -6.160907       -inf        0.0  MAXIMIZE
#  1     0.216502        0.0        1.0  MAXIMIZE
#  2     0.106029        0.0        1.0  MAXIMIZE
#  11 -229.480213       -inf        inf  MAXIMIZE
#  12    0.976095        0.0        1.0  MAXIMIZE
#  13    0.905729        0.0        1.0  MAXIMIZE
#  14    0.898860        0.0        1.0  MAXIMIZE
#  15    0.436199        0.0        1.0  MAXIMIZE
#  16    0.617264        0.0        1.0  MAXIMIZE  ,
#  -0.33325502447649114)

# %%
score = testModel(CTGAN, df_train['player_attributes'])
# Out:
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_data[pd.isnull(real_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\pandas\core\frame.py:3089: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   synthetic_data[pd.isnull(synthetic_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-04-01 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-23 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-13 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-27 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-01 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-05 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-10 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-06-06 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-19 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-26 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-26 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-22 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-16 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-10 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-10-04 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-21 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-02-11 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-10-30 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-12 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-09 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-27 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-18 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-03 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-07-26 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-07-25 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-06-30 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2008-02-22 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-10-11 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-12-27 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-28 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-24 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-14 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-05-30 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-26 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-08-07 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-02 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-26 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-12 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-16 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-06-09 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-01-28 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-12 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-19 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-06-16 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-26 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-06-07 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-07-26 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-04-01 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-12 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-03 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-27 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-29 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-03-08 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-21 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-01-28 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-02-27 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-23 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-01-07 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-12 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-31 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-03 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-01-14 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-05-09 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-12 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-08 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-01-09 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-03 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-03-22 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-10 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-01 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-18 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-24 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-04 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-09-23 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-13 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-25 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-06-12 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-10 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-17 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-15 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-31 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-24 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2008-02-22 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-04-21 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-04-10 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-05 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-15 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-17 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-21 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-10-11 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-11 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-10-31 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-06-06 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-03-08 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-02-20 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-08-15 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-26 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-10 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-10-04 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-06-05 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-26 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-24 00:00:00', attacking_work_rate='low') in synthetic data.
# ...
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-06-05 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-24 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2010-08-30 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-03-27 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-12-12 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-06-14 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-04-28 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-10-30 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-05-23 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-10-17 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-02-06 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-28 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-01 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-10-16 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-08-14 00:00:00', defensive_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-03-13 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-03-08 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-02-04 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-12 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-07-07 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-19 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-13 00:00:00', defensive_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-03-07 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-28 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-08-07 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-07-07 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-06-06 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-02-04 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-09 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-03 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-07-26 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-01-07 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-26 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-03-07 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-29 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-03-06 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-20 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-04-21 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-01-23 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-09-23 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2008-02-22 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-04-14 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-03-28 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-10-02 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-06-12 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-07-25 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-03-21 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-05 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-05-16 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(preferred_foot='left', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(preferred_foot='left', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='None', defensive_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='low', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='low', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='None', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='low', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='low', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')

# %%
score
# Out:
# (                    metric                                     name  \
#  0          BNLogLikelihood           BayesianNetwork Log Likelihood
#  1        LogisticDetection             LogisticRegression Detection
#  2             SVCDetection                            SVC Detection
#  11         GMLogLikelihood           GaussianMixture Log Likelihood
#  12                  CSTest                              Chi-Squared
#  13                  KSTest  Inverted Kolmogorov-Smirnov D statistic
#  14          KSTestExtended  Inverted Kolmogorov-Smirnov D statistic
#  15  ContinuousKLDivergence   Continuous Kullback–Leibler Divergence
#  16    DiscreteKLDivergence     Discrete Kullback–Leibler Divergence
#
#           score  min_value  max_value      goal
#  0   -10.872778       -inf        0.0  MAXIMIZE
#  1     0.025651        0.0        1.0  MAXIMIZE
#  2     0.000455        0.0        1.0  MAXIMIZE
#  11 -250.447761       -inf        inf  MAXIMIZE
#  12    0.930953        0.0        1.0  MAXIMIZE
#  13    0.773825        0.0        1.0  MAXIMIZE
#  14    0.779440        0.0        1.0  MAXIMIZE
#  15    0.349164        0.0        1.0  MAXIMIZE
#  16    0.414357        0.0        1.0  MAXIMIZE  ,
#  -0.9553328372753059)

# %%
score = testModel(CopulaGAN, df_train['player_attributes'])
# Out:
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\stats\_continuous_distns.py:4965: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\stats\_continuous_distns.py:621: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\copulas\univariate\truncated_gaussian.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   a = (self.min - loc) / scale
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\copulas\univariate\truncated_gaussian.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   b = (self.max - loc) / scale
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_data[pd.isnull(real_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\pandas\core\frame.py:3089: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   synthetic_data[pd.isnull(synthetic_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-12 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-05-23 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-05-30 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-07-25 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-02-11 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-26 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-08-07 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-10-30 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-03 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-12-27 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-16 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-28 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-10-04 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-21 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-26 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-31 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-06 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-14 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-13 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-07-26 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-06 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-10 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-01 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2008-02-22 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-06-06 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-27 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-05 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-09 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-16 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-02 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-10 00:00:00', preferred_foot='right') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-26 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-13 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-08-14 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-07-07 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-07 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-12 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-05 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-15 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-25 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-02-20 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-06-21 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-06-06 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-28 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-11 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-05-30 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-07-25 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-04-07 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-24 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-03 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-12-19 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-06-21 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-01 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-10-02 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-17 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-04-19 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-17 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-08-07 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-24 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-24 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-06-16 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-02-27 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-10 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-12-12 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-12 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-21 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-03-28 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-10-02 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-06-14 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-10-24 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-24 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-21 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-03 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-25 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-01-16 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-03-14 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-16 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-28 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-15 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-07-18 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-11-08 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-03-07 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-02-13 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-10 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-05-09 00:00:00', attacking_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-03-01 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-03 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-10 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-05-26 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-26 00:00:00', attacking_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-20 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# ...
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-06-05 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-02-18 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-16 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-10-02 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-10-24 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-19 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-04-28 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-14 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-22 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-03-27 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-05-22 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-17 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-08-02 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-31 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-10-16 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-04-14 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-10 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-04-10 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-01-14 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-03-01 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-06-12 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-04-07 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-10 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-14 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-17 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-11-12 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-07 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-10 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-07-16 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-03-22 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-13 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-11-07 00:00:00', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-09-13 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-03 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-10 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2007-08-30 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-03 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-27 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-03-31 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-01-10 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-24 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-05-17 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2013-12-13 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-12-27 00:00:00', defensive_work_rate='high') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-12-19 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-08-14 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2016-02-04 00:00:00', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-28 00:00:00', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-04-04 00:00:00', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(preferred_foot='left', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(preferred_foot='left', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='None', defensive_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='None', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='low', defensive_work_rate='o') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='low', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='high', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='low', defensive_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='low', defensive_work_rate='1') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='medium', defensive_work_rate='2') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')

# %%
score
# Out:
# (                    metric                                     name  \
#  0          BNLogLikelihood           BayesianNetwork Log Likelihood
#  1        LogisticDetection             LogisticRegression Detection
#  2             SVCDetection                            SVC Detection
#  11         GMLogLikelihood           GaussianMixture Log Likelihood
#  12                  CSTest                              Chi-Squared
#  13                  KSTest  Inverted Kolmogorov-Smirnov D statistic
#  14          KSTestExtended  Inverted Kolmogorov-Smirnov D statistic
#  15  ContinuousKLDivergence   Continuous Kullback–Leibler Divergence
#  16    DiscreteKLDivergence     Discrete Kullback–Leibler Divergence
#
#           score  min_value  max_value      goal
#  0   -10.972038       -inf        0.0  MAXIMIZE
#  1     0.083957        0.0        1.0  MAXIMIZE
#  2     0.002046        0.0        1.0  MAXIMIZE
#  11 -239.285902       -inf        inf  MAXIMIZE
#  12    0.963067        0.0        1.0  MAXIMIZE
#  13    0.815601        0.0        1.0  MAXIMIZE
#  14    0.820104        0.0        1.0  MAXIMIZE
#  15    0.323357        0.0        1.0  MAXIMIZE
#  16    0.448844        0.0        1.0  MAXIMIZE  ,
#  -0.9462775596021924)

# %%
score = testModel(TVAE, df_train['player_attributes'])
# Out:
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass n_components=10 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_data[pd.isnull(real_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\pandas\core\frame.py:3089: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   synthetic_data[pd.isnull(synthetic_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-21 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-10-02 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-01-30 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-10 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='None', defensive_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_data[pd.isnull(real_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\pandas\core\frame.py:3089: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   synthetic_data[pd.isnull(synthetic_data)] = 0.0
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-02-21 00:00:00', preferred_foot='left') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2014-10-02 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-01-30 00:00:00', attacking_work_rate='None') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(date='2015-12-10 00:00:00', attacking_work_rate='low') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# E:\ProgramData\Anaconda3\envs\master\lib\site-packages\sdmetrics\utils.py:62: UserWarning: Unexpected value Pandas(attacking_work_rate='None', defensive_work_rate='medium') in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')

# %%
score
# Out:
# (                    metric                                     name  \
#  0          BNLogLikelihood           BayesianNetwork Log Likelihood
#  1        LogisticDetection             LogisticRegression Detection
#  2             SVCDetection                            SVC Detection
#  11         GMLogLikelihood           GaussianMixture Log Likelihood
#  12                  CSTest                              Chi-Squared
#  13                  KSTest  Inverted Kolmogorov-Smirnov D statistic
#  14          KSTestExtended  Inverted Kolmogorov-Smirnov D statistic
#  15  ContinuousKLDivergence   Continuous Kullback–Leibler Divergence
#  16    DiscreteKLDivergence     Discrete Kullback–Leibler Divergence
#
#           score  min_value  max_value      goal
#  0    -4.631169       -inf        0.0  MAXIMIZE
#  1     0.000000        0.0        1.0  MAXIMIZE
#  2     0.000000        0.0        1.0  MAXIMIZE
#  11 -246.879999       -inf        inf  MAXIMIZE
#  12    0.988816        0.0        1.0  MAXIMIZE
#  13    0.674349        0.0        1.0  MAXIMIZE
#  14    0.685070        0.0        1.0  MAXIMIZE
#  15    0.427598        0.0        1.0  MAXIMIZE
#  16    0.672091        0.0        1.0  MAXIMIZE  ,
#  -0.24258274458808296)

# %%
text = "E:/GitHub Repos/TensorFlow training/SoccerDataset/database.sqlite"
asd = text.split('.')

# %%
asd[-1]
# Out:
# 'sqlite'

# %%
len(asd)
# Out:
# 2

# %%
if len(asd) < 2:
    print("asd")
